# %%
library(ggplot2)
setwd("C:\\Users\\Lenovo\\Desktop\\Refactored_Py_DS_ML_Bootcamp-master\\Python-board-infinity\\R project")
library('dplyr')
df<-read.csv("cleaned_job_dataset.csv",stringsAsFactors=FALSE)
#head(df)

# %%
colnames(df)
# Out:
#  [1] "Job.Title"         "Job.Description"   "Rating"
#  [4] "Company.Name"      "Location"          "Headquarters"
#  [7] "Size"              "Founded"           "Type.of.ownership"
# [10] "Industry"          "Sector"            "Revenue"
# [13] "Competitors"       "Python"            "R.Prog"
# [16] "Excel"             "Hadoop"            "SQL"
# [19] "SAS"

# %% [markdown]
# # Motivation

# %% [markdown]
# Due to covid 19 company are hiring less candidate in India. So I have scrap, cleaned and analyzed the Glassdoor jobs posting data of data scientist, engineer, analyst in this COVID 19 situation in India

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Q1. What are the key skills reuirement for data science domain

# %%
print(count(df,Python))
print("-------")
print(count(df,R.Prog))
print("-------")
print(count(df,SAS))
print("-------")
print(count(df,Excel))
print("-------")
print(count(df,SQL))
print("-------")
print(count(df,Hadoop))
# Out:
#   Python   n
# 1      0 333
# 2      1 552
# [1] "-------"
#   R.Prog   n
# 1      0 858
# 2      1  27
# [1] "-------"
#   SAS   n
# 1   0 762
# 2   1 123
# [1] "-------"
#   Excel   n
# 1     0 452
# 2     1 433
# [1] "-------"
#   SQL   n
# 1   0 413
# 2   1 472
# [1] "-------"
#   Hadoop   n
# 1      0 677
# 2      1 208

# %% [markdown]
# 1. As we can see Python is on of the key requirement in jobs
#
# 2. R is not requirement for companies compare to python
#
# 3. Excel and SQL has good number of requirement
#
# 4. Hadoop requirement is low but high compare to R programming

# %%
structure<-ggplot(gb)

# %%
gb <- df %>% group_by(Job.Title)%>% summarise(
 count=n()
)
gb
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   Job.Title                 count
# 1 Data Analyst              228
# 2 Data Engineer              77
# 3 Data Scientist            546
# 4 Machine Learning Engineer  34

# %% [markdown]
# We have different post with different count we have to use percentage in order to check the skills in different job titles

# %%
gb <- df %>% group_by(Job.Title)%>% summarise(
  Python = round(sum(Python)/n(),2)*100,
  R.Prog = round(sum(R.Prog)/n(),2)*100,
  Excel = round(sum(Excel)/n(),2)*100,
  Hadoop = round(sum(Hadoop)/n(),2)*100,
  SAS = round(sum(SAS)/n(),2)*100,
  SQL = round(sum(SQL)/n(),2)*100
)
gb # Percentage of skills contain in job title
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   Job.Title                 Python R.Prog Excel Hadoop SAS SQL
# 1 Data Analyst              44     1      71     5     12  54
# 2 Data Engineer             75     1      70    57      3  87
# 3 Data Scientist            69     4      38    27     17  51
# 4 Machine Learning Engineer 50     3      26     9      0  18

# %%
structure<-ggplot(gb)

# %%
structure+geom_col(aes(x=Job.Title,y=Python),fill = "lightgreen")+
theme(axis.title.x=element_text(colour='black',size=16),
        axis.title.y=element_text(colour='black',size=16),
        axis.text.x=element_text(colour='darkgreen',size=13),
        axis.text.y=element_text(colour='darkgreen',size=13),
        legend.title=element_text(colour='black',size=20),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=12, repr.plot.height=6)
# Out:
# plot without title

# %% [markdown]
# Data Scientist and Data Engineer jobs require Python more than 60% of the time
#
# Machine Learning Engineer and Data Analyst require Python more than 40-45% of the time

# %%
structure+geom_col(aes(x=Job.Title,y=R.Prog))+
theme(axis.title.x=element_text(colour='black',size=16),
        axis.title.y=element_text(colour='black',size=16),
        axis.text.x=element_text(colour='darkgreen',size=13),
        axis.text.y=element_text(colour='darkgreen',size=13),
        legend.title=element_text(colour='black',size=20),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=12, repr.plot.height=6)
# Out:
# plot without title

# %% [markdown]
# Data Scientist and machine Learning Engineer jobs requirement has R Programming comparatively than Data engineer and Data analyst
#
# But yes it is a low demanding skills as the highest job title require R Programming 4% of the time

# %%
structure+geom_col(aes(x=Job.Title,y=SQL), fill = 'purple')+
theme(axis.title.x=element_text(colour='black',size=16),
        axis.title.y=element_text(colour='black',size=16),
        axis.text.x=element_text(colour='darkgreen',size=13),
        axis.text.y=element_text(colour='darkgreen',size=13),
        legend.title=element_text(colour='black',size=20),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=12, repr.plot.height=6)
# Out:
# plot without title

# %% [markdown]
# interestingly Data Engineer, Data Analyst and Data Scientist jobs requires SQL more than 50% of the time

# %%
structure+geom_col(aes(x=Job.Title,y=Hadoop),fill='black')+
theme(axis.title.x=element_text(colour='black',size=16),
        axis.title.y=element_text(colour='black',size=16),
        axis.text.x=element_text(colour='darkgreen',size=13),
        axis.text.y=element_text(colour='darkgreen',size=13),
        legend.title=element_text(colour='black',size=20),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=12, repr.plot.height=6)
# Out:
# plot without title

# %% [markdown]
# As we know Data engineer job should have highest requirement of Hadoop in their skill set

# %%
structure+geom_col(aes(x=Job.Title,y=Excel),fill='violet')+
theme(axis.title.x=element_text(colour='black',size=16),
        axis.title.y=element_text(colour='black',size=16),
        axis.text.x=element_text(colour='darkgreen',size=13),
        axis.text.y=element_text(colour='darkgreen',size=13),
        legend.title=element_text(colour='black',size=20),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=12, repr.plot.height=6)
# Out:
# plot without title

# %% [markdown]
# Data Analyst and Data Engineer require Excel as their skill as it require more than 60% of the time

# %% [markdown]
# ### Q2. What are the location one should look for?

# %%
str<-ggplot(df[!df$Location=='-1',])

# %%
str+geom_bar(aes(x=Location),fill='darkgreen')+
theme(axis.title.x=element_text(colour='black',size=20),
        axis.title.y=element_text(colour='black',size=20),
        axis.text.x=element_text(colour='darkgreen',size=16,angle = 90),
        axis.text.y=element_text(colour='darkgreen',size=15),
        legend.title=element_text(colour='black',size=20),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=20, repr.plot.height=8)
# Out:
# plot without title

# %% [markdown]
# Begaluru, Mumbai, Pune, Hyderabad has comparatively more Open Position of Data Science related posting

# %% [markdown]
# ### Q3. Size of companies which are actively hiring?

# %%
str<-ggplot(df[!df$Size=='-1',])
str+geom_bar(aes(x=Size),fill='orange')+
theme(axis.title.x=element_text(colour='black',size=20),
        axis.title.y=element_text(colour='black',size=20),
        axis.text.x=element_text(colour='darkgreen',size=16,angle = 90),
        axis.text.y=element_text(colour='darkgreen',size=15),
        legend.title=element_text(colour='black',size=20),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=20, repr.plot.height=8)
# Out:
# plot without title

# %% [markdown]
# Looks like startups and MNC's are hiring in this COVID 19 situation

# %% [markdown]
# ### Q4. Types of Companies hiring Public or Private ?

# %%
str<-ggplot(df[!df$Type.of.ownership=='-1' & !df$Type.of.ownership=='Non-profit Organisation',])
str+geom_bar(aes(x=Type.of.ownership),fill='lightgreen')+
theme(axis.title.x=element_text(colour='black',size=20),
        axis.title.y=element_text(colour='black',size=20),
        axis.text.x=element_text(colour='darkgreen',size=16,angle = 90),
        axis.text.y=element_text(colour='darkgreen',size=15),
        legend.title=element_text(colour='black',size=20),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=20, repr.plot.height=8)
# Out:
# plot without title

# %% [markdown]
# Looks like Private companies are hiring more than public sector companies

# %% [markdown]
# ### Q5. Types of Industry which are on hiring spree ?

# %%
str<-ggplot(df[!df$Industry=='-1',])
str+geom_bar(aes(x=Industry),fill='lightgreen')+
theme(axis.title.x=element_text(colour='black',size=25),
        axis.title.y=element_text(colour='black',size=25),
        axis.text.x=element_text(colour='darkgreen',size=16,angle = 90),
        axis.text.y=element_text(colour='darkgreen',size=15),
        legend.title=element_text(colour='black',size=25),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=25, repr.plot.height=15)
# Out:
# plot without title

# %% [markdown]
# Looks like IT Services has the highest number of active hiring going on
# Industries like Staffing and Outsourcing, Consulting, Computer Hardware and Software, Enterprise Software and Network Solution and Biotech & Pharmaceuticals has also more number of active hiring

# %% [markdown]
# ### Q5. Types of Sectors which are on hiring spree ??

# %%
str<-ggplot(df[!df$Sector=='-1',])
str+geom_bar(aes(x=Sector),fill='lightblue')+
theme(axis.title.x=element_text(colour='black',size=25),
        axis.title.y=element_text(colour='black',size=25),
        axis.text.x=element_text(colour='darkgreen',size=16,angle = 90),
        axis.text.y=element_text(colour='darkgreen',size=15),
        legend.title=element_text(colour='black',size=25),
        legend.text=element_text(colour='black',size=20))
options(repr.plot.width=25, repr.plot.height=15)
# Out:
# plot without title

# %% [raw]
# As we can see IT Sector is actively hiring more number of Candidate than other sectors
# Business Service, Biotech & Pharmaceuticals and Finance Sectors are comparatively hiring more number of candidate

# %% [markdown]
# ### Q7. Companies one should look for?

# %%
gb <- df %>% group_by(Company.Name)%>% summarise(
  count=n())%>%top_n(35)
gb$Company.Name
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#
# Selecting by count
#  [1] "Amazon"
#  [2] "Approgence"
#  [3] "BuzzBoard"
#  [4] "Capgemini"
#  [5] "CIEL HR Services"
#  [6] "Citi"
#  [7] "Cleartrip"
#  [8] "Copiousminds"
#  [9] "Crescendo Global Services"
# [10] "Dasceq"
# [11] "dunnhumby"
# [12] "EY"
# [13] "FLEXILOANS TECHNOLOGIES"
# [14] "GP Strategies"
# [15] "GSK"
# [16] "Happy Marketer"
# [17] "Honeywell"
# [18] "Institutional Shareholder Services, Inc."
# [19] "J.P. Morgan"
# [20] "Khoros, LLC"
# [21] "Kwalee"
# [22] "Live Connections"
# [23] "LogisticsNow"
# [24] "Lynkit"
# [25] "Magna Infotech (India)"
# [26] "Matelabs Innovations Pvt. Ltd."
# [27] "Novartis"
# [28] "PayPal"
# [29] "Pype"
# [30] "Quantzig"
# [31] "Rubicon Red"
# [32] "Sanofi"
# [33] "String Bio"
# [34] "The Edge Asia"
# [35] "Think Analytics India"
# [36] "Walmart"
# [37] "WDB Inida Private Limited"
# [38] "ZoomRx"

# %% [raw]
# These are the companies who are currently hiring for multiple positions with various job titles

# %% [markdown]
# ## Insights

# %% [markdown]
# 1. As we can see Python is on of the key requirement in jobs
# 2. R is not requirement for companies compare to python
# 3. Excel and SQL has good number of requirement
# 4. Hadoop requirement is low but high compare to R programming
# 5. Data Scientist and Data Engineer jobs require Python more than 60% of the time
# 6. Machine Learning Engineer and Data Analyst require Python more than 40-45% of the time
# 7. Data Scientist and machine Learning Engineer jobs requirement has R Programming comparatively than Data engineer and Data analyst
# 8. But yes it is a low demanding skills as the highest job title require R Programming 4% of the time
# 9. Interestingly Data Engineer, Data Analyst and Data Scientist jobs requires SQL more than 50% of the time
# 10. Data engineer job should have highest requirement of Hadoop in their skill set
# 11. Data Analyst and Data Engineer require Excel as their skill as it require more than 60% of the time
# 12. Begaluru, Mumbai, Pune, Hyderabad has comparatively more Open Position of Data Science related posting
# 13. Startups and MNC's are hiring in this COVID 19 situation
# 14. Private companies are hiring more than public sector companies
# 15. IT Services has the highest number of active hiring going on
# 16. Industries like Staffing and Outsourcing, Consulting, Computer Hardware and Software, Enterprise Software and   Network Solution and Biotech & Pharmaceuticals has also more number of active hiring
# 17. IT Sector is actively hiring more number of Candidate than other sectors
# 18. Business Service, Biotech & Pharmaceuticals and Finance Sectors are comparatively hiring more number of candidate

# %% [markdown]
# ## Conclusions

# %% [markdown]
# **For different titles you can focus on different skills like**
#
#   1. For Data Scientist Position : Python, R programming(optional), SQL
#   2. For Data Analyst Position : Python, SQL, Excel
#   3. For Data Engineer Position : Python, SQL, Excel, Hadoop
#   4. For Machine Learning Engineer : Python, R programming(optional)

# %% [markdown]
# **If you are looking for jobs try to find jobs in**
#   1. Cities like Begaluru, Mumbai, Pune, Hyderabad
#   2. Find jobs in Startups and MNC's as they are on hiring spree
#   3. Find jobs in Private companies
#   4. Try IT Services industry as they are hiring in high numbers
#   5. Also try Industries like Staffing and Outsourcing, Consulting, Computer Hardware and Software, Enterprise Software        and Network Solution and Biotech & Pharmaceuticals
#   6. Again IT Sector is actively hiring more number of Candidate
#   7. Try to find jobs in Industries like Business Service, Biotech & Pharmaceuticals and Finance Sectors

# %% [markdown]
# **If you are looking for companies to apply for try**
#
#     'Amazon' 'Approgence' 'BuzzBoard' 'Capgemini' 'CIEL HR Services' 'Citi' 'Cleartrip' 'Copiousminds' 'Crescendo Global Services' 'Dasceq''dunnhumby' 'EY' 'FLEXILOANS TECHNOLOGIES' 'GP Strategies''GSK' 'Happy Marketer' 'Honeywell' 'Institutional Shareholder Services, Inc.' 'J.P. Morgan' 'Khoros, LLC' 'Kwalee' 'Live Connections' 'LogisticsNow' 'Lynkit''Magna Infotech (India)' 'Matelabs Innovations Pvt. Ltd.' 'Novartis' 'PayPal' 'Pype' 'Quantzig' 'Rubicon Red' 'Sanofi' 'String Bio' 'The Edge Asia' 'Think Analytics India' 'Walmart' 'WDB Inida Private Limited' 'ZoomRx' they are the companies who are currently hiring for multiple positions with various job titles
